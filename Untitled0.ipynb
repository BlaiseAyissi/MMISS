# %% [markdown]
# <a href="https://colab.research.google.com/github/BlaiseAyissi/MMISS/blob/v2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.chdir('MMISS')

# %%
! git clone https://github.com/BlaiseAyissi/MMISS
# Out:
# Cloning into 'MMISS'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 75 (delta 18), reused 72 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 133.83 KiB | 792.00 KiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
! pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 13.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.7/212.7 kB 12.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 45.6 MB/s eta 0:00:00
# ...

# %%
! wget https://huggingface.co/datasets/axiong/pmc_oa/resolve/main/images.zip
! wget https://huggingface.co/datasets/axiong/pmc_oa/resolve/main/pmc_oa.jsonl
# Out:
# --2024-11-02 20:16:50--  https://huggingface.co/datasets/axiong/pmc_oa/resolve/main/images.zip
# Resolving huggingface.co (huggingface.co)... 3.165.160.11, 3.165.160.61, 3.165.160.12, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.11|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from zipfile import ZipFile

file_name = "images.zip"
with ZipFile(file_name, 'r') as zip:
  zip.printdir()
  print('Extracting all the files now...')
  zip.extractall()
  print('Done!')
# Out:
# Streaming output truncated to the last 5000 lines.
# caption_T060_filtered_top4_sep_v0_subfigures/PMC5563370_F2_205263.jpg 2022-11-25 09:24:46         8520
# caption_T060_filtered_top4_sep_v0_subfigures/PMC8550605_Fig20_97809.jpg 2022-11-24 19:17:58         9734
# caption_T060_filtered_top4_sep_v0_subfigures/PMC7875629_fig1_365514.jpg 2022-11-25 06:34:24         3359
# caption_T060_filtered_top4_sep_v0_subfigures/PMC8466939_cells-10-02396-f002_67125.jpg 2022-11-24 17:50:36        17445
# caption_T060_filtered_top4_sep_v0_subfigures/PMC4398568_pone.0122562.g008_378562.jpg 2022-11-25 07:23:52         6470
# caption_T060_filtered_top4_sep_v0_subfigures/PMC7719266_biomedicines-08-00456-f003_315875.jpg 2022-11-25 04:40:46         8664
# caption_T060_filtered_top4_sep_v0_subfigures/PMC6073376_ijms-19-02080-f002_349575.jpg 2022-11-25 11:45:14        10566
# caption_T060_filtered_top4_sep_v0_subfigures/PMC5830446_Fig5_281726.jpg 2022-11-25 11:14:18         4466
# ...

# %%
! pip install fairscale
! pip install ruamel.yaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 28.4 MB/s eta 0:00:00
# ...

# %%
! python pretrain.py
# Out:
# python: can't open file 'C:\\Users\\Blaise\\pretrain.py': [Errno 2] No such file or directory
